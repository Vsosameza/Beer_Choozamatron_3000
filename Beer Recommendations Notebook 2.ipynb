# %% [markdown]
# ## Importing Dependencies

# %%
import pandas as pd
import numpy as np
import csv
from datetime import date
import matplotlib.pyplot as plt
# %matplotlib inline

import seaborn as sns
import sklearn

# %% [markdown]
# ## Parsing the data

# %%
df=pd.read_csv('beer_reviews.csv')
df.columns
# Out:
# Index(['brewery_id', 'brewery_name', 'review_time', 'review_overall',
#        'review_aroma', 'review_appearance', 'review_profilename', 'beer_style',
#        'review_palate', 'review_taste', 'beer_name', 'beer_abv',
#        'beer_beerid'],
#       dtype='object')

# %%
df.drop(['brewery_id', 'review_time'], axis=1, inplace=True)
df.head()
# Out:
#               brewery_name  review_overall  review_aroma  review_appearance  \
# 0          Vecchio Birraio             1.5           2.0                2.5
# 1          Vecchio Birraio             3.0           2.5                3.0
# 2          Vecchio Birraio             3.0           2.5                3.0
# 3          Vecchio Birraio             3.0           3.0                3.5
# 4  Caldera Brewing Company             4.0           4.5                4.0
#
#   review_profilename                      beer_style  review_palate  \
# 0            stcules                      Hefeweizen            1.5
# 1            stcules              English Strong Ale            3.0
# 2            stcules          Foreign / Export Stout            3.0
# 3            stcules                 German Pilsener            2.5
# 4     johnmichaelsen  American Double / Imperial IPA            4.0
#
#    review_taste               beer_name  beer_abv  beer_beerid
# 0           1.5            Sausa Weizen       5.0        47986
# 1           3.0                Red Moon       6.2        48213
# 2           3.0  Black Horse Black Beer       6.5        48215
# 3           3.0              Sausa Pils       5.0        47969
# 4           4.5           Cauldron DIPA       7.7        64883

# %%
reviews = dict()
for col in df.columns:
    reviews.update({
            col:df[col]
        })

reviews
# Out:
# {'beer_abv': 0          5.0
#  1          6.2
#  2          6.5
#  3          5.0
#  4          7.7
#  5          4.7
#  6          4.7
#  7          4.7
#  8          4.7
#  9          4.7
#  10         3.5
#  11         4.7
#  12         4.7
#  13         4.7
#  14         4.7
#  15         7.2
#  16         7.2
#  17         5.6
#  18         3.5
#  19         7.4
#  20         7.4
#  21         7.4
#  22         7.4
#  23         7.4
#  24         7.4
#  25         7.4
#  26         7.4
#  27         7.4
#  28         7.4
#  29         7.4
#            ...
#  1586584    5.8
#  1586585    5.8
#  1586586    5.8
#  1586587    NaN
#  1586588    8.0
#  1586589    8.0
#  1586590    8.0
#  1586591    8.0
#  1586592    5.2
#  1586593    5.2
#  1586594    6.0
#  1586595    5.0
#  1586596    NaN
#  1586597    NaN
#  1586598    NaN
#  1586599    9.0
#  1586600    5.2
#  1586601    5.2
#  1586602    5.2
#  1586603    5.2
#  1586604    5.2
#  1586605    5.2
#  1586606    5.2
#  1586607    5.2
#  1586608    5.2
#  1586609    5.2
#  1586610    5.2
#  1586611    5.2
#  1586612    5.2
#  1586613    5.2
#  Name: beer_abv, Length: 1586614, dtype: float64,
#  'beer_beerid': 0          47986
#  1          48213
#  2          48215
#  3          47969
#  4          64883
#  5          52159
#  6          52159
#  7          52159
#  8          52159
#  9          52159
#  10           436
#  11         52159
#  12         52159
#  13         52159
#  14         52159
#  15         10789
#  16         10789
#  17         12386
#  18           436
#  19         58046
#  20         58046
#  21         58046
#  22         58046
#  23         58046
#  24         58046
#  25         58046
#  26         58046
#  27         58046
#  28         58046
#  29         58046
#             ...
#  1586584    34215
#  1586585    34215
#  1586586    34215
#  1586587    36555
#  1586588    62147
#  1586589    62147
#  1586590    62147
#  1586591    62147
#  1586592    41749
#  1586593    41749
#  1586594    38160
#  1586595    71234
#  1586596    48360
#  1586597    48360
#  1586598    48360
#  1586599    43233
#  1586600    33061
#  1586601    33061
#  1586602    33061
#  1586603    33061
#  1586604    33061
#  1586605    33061
#  1586606    33061
#  1586607    33061
#  1586608    33061
#  1586609    33061
#  1586610    33061
#  1586611    33061
#  1586612    33061
#  1586613    33061
#  Name: beer_beerid, Length: 1586614, dtype: int64,
#  'beer_name': 0                    Sausa Weizen
#  1                        Red Moon
#  2          Black Horse Black Beer
#  3                      Sausa Pils
#  4                   Cauldron DIPA
#  5             Caldera Ginger Beer
#  6             Caldera Ginger Beer
#  7             Caldera Ginger Beer
#  8             Caldera Ginger Beer
#  9             Caldera Ginger Beer
#  10                   Amstel Light
#  11            Caldera Ginger Beer
#  12            Caldera Ginger Beer
#  13            Caldera Ginger Beer
#  14            Caldera Ginger Beer
#  15          Caldera Oatmeal Stout
#  16          Caldera Oatmeal Stout
#  17                 Caldera OBF 15
#  18                   Amstel Light
#  19                  Rauch Ür Bock
#  20                  Rauch Ür Bock
#  21                  Rauch Ür Bock
#  22                  Rauch Ür Bock
#  23                  Rauch Ür Bock
#  24                  Rauch Ür Bock
#  25                  Rauch Ür Bock
#  26                  Rauch Ür Bock
#  27                  Rauch Ür Bock
#  28                  Rauch Ür Bock
#  29                  Rauch Ür Bock
#                      ...
#  1586584           Big Thumper Ale
#  1586585           Big Thumper Ale
#  1586586           Big Thumper Ale
#  1586587                   Maibock
#  1586588         Bear Mountain Ale
#  1586589         Bear Mountain Ale
#  1586590         Bear Mountain Ale
#  1586591         Bear Mountain Ale
#  1586592               Irish Amber
#  1586593               Irish Amber
#  1586594           Highland Porter
#  1586595          Baron Von Weizen
#  1586596             Resolution #2
#  1586597             Resolution #2
#  1586598             Resolution #2
#  1586599                Double IPA
#  1586600        The Horseman's Ale
#  1586601        The Horseman's Ale
#  1586602        The Horseman's Ale
#  1586603        The Horseman's Ale
#  1586604        The Horseman's Ale
#  1586605        The Horseman's Ale
#  1586606        The Horseman's Ale
#  1586607        The Horseman's Ale
#  1586608        The Horseman's Ale
#  1586609        The Horseman's Ale
#  1586610        The Horseman's Ale
#  1586611        The Horseman's Ale
#  1586612        The Horseman's Ale
#  1586613        The Horseman's Ale
#  Name: beer_name, Length: 1586614, dtype: object,
#  'beer_style': 0                                   Hefeweizen
#  1                           English Strong Ale
#  2                       Foreign / Export Stout
#  3                              German Pilsener
#  4               American Double / Imperial IPA
#  5                         Herbed / Spiced Beer
#  6                         Herbed / Spiced Beer
#  7                         Herbed / Spiced Beer
#  8                         Herbed / Spiced Beer
#  9                         Herbed / Spiced Beer
#  10                                 Light Lager
#  11                        Herbed / Spiced Beer
#  12                        Herbed / Spiced Beer
#  13                        Herbed / Spiced Beer
#  14                        Herbed / Spiced Beer
#  15                               Oatmeal Stout
#  16                               Oatmeal Stout
#  17                         American Pale Lager
#  18                                 Light Lager
#  19                                   Rauchbier
#  20                                   Rauchbier
#  21                                   Rauchbier
#  22                                   Rauchbier
#  23                                   Rauchbier
#  24                                   Rauchbier
#  25                                   Rauchbier
#  26                                   Rauchbier
#  27                                   Rauchbier
#  28                                   Rauchbier
#  29                                   Rauchbier
#                            ...
#  1586584    Extra Special / Strong Bitter (ESB)
#  1586585    Extra Special / Strong Bitter (ESB)
#  1586586    Extra Special / Strong Bitter (ESB)
#  1586587                  Maibock / Helles Bock
#  1586588                            Belgian IPA
#  1586589                            Belgian IPA
#  1586590                            Belgian IPA
#  1586591                            Belgian IPA
#  1586592                          Irish Red Ale
#  1586593                          Irish Red Ale
#  1586594                        American Porter
#  1586595                             Hefeweizen
#  1586596                Belgian Strong Pale Ale
#  1586597                Belgian Strong Pale Ale
#  1586598                Belgian Strong Pale Ale
#  1586599         American Double / Imperial IPA
#  1586600                            Pumpkin Ale
#  1586601                            Pumpkin Ale
#  1586602                            Pumpkin Ale
#  1586603                            Pumpkin Ale
#  1586604                            Pumpkin Ale
#  1586605                            Pumpkin Ale
#  1586606                            Pumpkin Ale
#  1586607                            Pumpkin Ale
#  1586608                            Pumpkin Ale
#  1586609                            Pumpkin Ale
#  1586610                            Pumpkin Ale
#  1586611                            Pumpkin Ale
#  1586612                            Pumpkin Ale
#  1586613                            Pumpkin Ale
#  Name: beer_style, Length: 1586614, dtype: object,
#  'brewery_name': 0                      Vecchio Birraio
#  1                      Vecchio Birraio
#  2                      Vecchio Birraio
#  3                      Vecchio Birraio
#  4              Caldera Brewing Company
#  5              Caldera Brewing Company
#  6              Caldera Brewing Company
#  7              Caldera Brewing Company
#  8              Caldera Brewing Company
#  9              Caldera Brewing Company
#  10              Amstel Brouwerij B. V.
#  11             Caldera Brewing Company
#  12             Caldera Brewing Company
#  13             Caldera Brewing Company
#  14             Caldera Brewing Company
#  15             Caldera Brewing Company
#  16             Caldera Brewing Company
#  17             Caldera Brewing Company
#  18              Amstel Brouwerij B. V.
#  19             Caldera Brewing Company
#  20             Caldera Brewing Company
#  21             Caldera Brewing Company
#  22             Caldera Brewing Company
#  23             Caldera Brewing Company
#  24             Caldera Brewing Company
#  25             Caldera Brewing Company
#  26             Caldera Brewing Company
#  27             Caldera Brewing Company
#  28             Caldera Brewing Company
#  29             Caldera Brewing Company
#                        ...
#  1586584    The Defiant Brewing Company
#  1586585    The Defiant Brewing Company
#  1586586    The Defiant Brewing Company
#  1586587    The Defiant Brewing Company
#  1586588    The Defiant Brewing Company
#  1586589    The Defiant Brewing Company
#  1586590    The Defiant Brewing Company
#  1586591    The Defiant Brewing Company
#  1586592    The Defiant Brewing Company
#  1586593    The Defiant Brewing Company
#  1586594    The Defiant Brewing Company
#  1586595    The Defiant Brewing Company
#  1586596    The Defiant Brewing Company
#  1586597    The Defiant Brewing Company
#  1586598    The Defiant Brewing Company
#  1586599    The Defiant Brewing Company
#  1586600    The Defiant Brewing Company
#  1586601    The Defiant Brewing Company
#  1586602    The Defiant Brewing Company
#  1586603    The Defiant Brewing Company
#  1586604    The Defiant Brewing Company
#  1586605    The Defiant Brewing Company
#  1586606    The Defiant Brewing Company
#  1586607    The Defiant Brewing Company
#  1586608    The Defiant Brewing Company
#  1586609    The Defiant Brewing Company
#  1586610    The Defiant Brewing Company
#  1586611    The Defiant Brewing Company
#  1586612    The Defiant Brewing Company
#  1586613    The Defiant Brewing Company
#  Name: brewery_name, Length: 1586614, dtype: object,
#  'review_appearance': 0          2.5
#  1          3.0
#  2          3.0
#  3          3.5
#  4          4.0
#  5          3.5
#  6          3.5
#  7          3.5
#  8          3.5
#  9          5.0
#  10         3.0
#  11         4.0
#  12         4.0
#  13         3.0
#  14         3.0
#  15         2.5
#  16         2.5
#  17         4.0
#  18         3.0
#  19         3.0
#  20         4.0
#  21         4.0
#  22         4.5
#  23         4.0
#  24         4.0
#  25         3.5
#  26         4.0
#  27         4.0
#  28         3.5
#  29         4.0
#            ...
#  1586584    4.0
#  1586585    3.5
#  1586586    3.5
#  1586587    4.0
#  1586588    3.0
#  1586589    4.5
#  1586590    4.0
#  1586591    3.0
#  1586592    4.0
#  1586593    4.5
#  1586594    4.0
#  1586595    4.0
#  1586596    5.0
#  1586597    4.0
#  1586598    3.5
#  1586599    4.0
#  1586600    3.5
#  1586601    4.0
#  1586602    4.0
#  1586603    4.0
#  1586604    4.5
#  1586605    5.0
#  1586606    4.0
#  1586607    4.5
#  1586608    4.0
#  1586609    3.5
#  1586610    2.5
#  1586611    3.0
#  1586612    4.5
#  1586613    4.5
#  Name: review_appearance, Length: 1586614, dtype: float64,
#  'review_aroma': 0          2.0
#  1          2.5
#  2          2.5
#  3          3.0
#  4          4.5
#  5          3.5
#  6          3.5
#  7          2.5
#  8          3.0
#  9          3.5
#  10         2.0
#  11         5.0
#  12         4.0
#  13         4.5
#  14         4.0
#  15         3.0
#  16         1.5
#  17         3.0
#  18         3.0
#  19         4.5
#  20         4.0
#  21         4.5
#  22         5.0
#  23         4.5
#  24         4.5
#  25         5.0
#  26         4.5
#  27         5.0
#  28         4.5
#  29         4.5
#            ...
#  1586584    4.0
#  1586585    3.5
#  1586586    3.5
#  1586587    4.5
#  1586588    2.5
#  1586589    4.0
#  1586590    3.5
#  1586591    2.0
#  1586592    3.5
#  1586593    4.0
#  1586594    3.5
#  1586595    3.5
#  1586596    3.0
#  1586597    4.5
#  1586598    4.0
#  1586599    4.5
#  1586600    4.0
#  1586601    4.0
#  1586602    4.0
#  1586603    4.5
#  1586604    4.5
#  1586605    5.0
#  1586606    4.5
#  1586607    5.0
#  1586608    4.0
#  1586609    4.0
#  1586610    5.0
#  1586611    3.5
#  1586612    4.5
#  1586613    4.5
#  Name: review_aroma, Length: 1586614, dtype: float64,
#  'review_overall': 0          1.5
#  1          3.0
#  2          3.0
#  3          3.0
#  4          4.0
#  5          3.0
#  6          3.5
#  7          3.0
#  8          4.0
#  9          4.5
#  10         3.0
#  11         5.0
#  12         4.0
#  13         4.0
#  14         3.5
#  15         3.0
#  16         2.0
#  17         4.0
#  18         2.5
#  19         4.5
#  20         4.0
#  21         4.0
#  22         4.5
#  23         4.0
#  24         4.5
#  25         5.0
#  26         4.5
#  27         4.5
#  28         4.5
#  29         4.5
#            ...
#  1586584    4.5
#  1586585    3.5
#  1586586    3.5
#  1586587    3.5
#  1586588    2.0
#  1586589    1.0
#  1586590    1.5
#  1586591    1.0
#  1586592    4.5
#  1586593    4.5
#  1586594    3.0
#  1586595    4.0
#  1586596    4.0
#  1586597    4.5
#  1586598    4.0
#  1586599    3.5
#  1586600    3.5
#  1586601    4.5
#  1586602    4.0
#  1586603    4.0
#  1586604    4.0
#  1586605    5.0
#  1586606    5.0
#  1586607    5.0
#  1586608    3.5
#  1586609    5.0
#  1586610    4.0
#  1586611    4.5
#  1586612    4.0
#  1586613    5.0
#  Name: review_overall, Length: 1586614, dtype: float64,
#  'review_palate': 0          1.5
#  1          3.0
#  2          3.0
#  3          2.5
#  4          4.0
#  5          3.0
#  6          4.0
#  7          2.0
#  8          3.5
#  9          4.0
#  10         2.5
#  11         4.0
#  12         3.5
#  13         2.5
#  14         3.0
#  15         3.0
#  16         2.5
#  17         4.0
#  18         2.0
#  19         4.0
#  20         3.0
#  21         3.5
#  22         4.0
#  23         4.0
#  24         4.0
#  25         3.5
#  26         4.0
#  27         4.0
#  28         4.0
#  29         4.0
#            ...
#  1586584    4.0
#  1586585    3.5
#  1586586    3.5
#  1586587    4.5
#  1586588    2.0
#  1586589    3.0
#  1586590    3.0
#  1586591    2.0
#  1586592    4.0
#  1586593    4.0
#  1586594    4.0
#  1586595    4.0
#  1586596    4.0
#  1586597    4.0
#  1586598    4.0
#  1586599    4.0
#  1586600    3.0
#  1586601    4.5
#  1586602    4.0
#  1586603    4.0
#  1586604    3.5
#  1586605    5.0
#  1586606    5.0
#  1586607    5.0
#  1586608    3.5
#  1586609    4.0
#  1586610    2.0
#  1586611    3.5
#  1586612    4.5
#  1586613    4.5
#  Name: review_palate, Length: 1586614, dtype: float64,
#  'review_profilename': 0                   stcules
#  1                   stcules
#  2                   stcules
#  3                   stcules
#  4            johnmichaelsen
#  5                   oline73
#  6                 Reidrover
#  7              alpinebryant
#  8             LordAdmNelson
#  9              augustgarage
#  10                  fodeeoz
#  11             MadeInOregon
#  12                  rawthar
#  13              Halcyondays
#  14              RangerClegg
#  15         Beerandraiderfan
#  16               RedDiamond
#  17               beerguy101
#  18                   jdhilt
#  19              UCLABrewN84
#  20               zaphodchak
#  21                  Tilley4
#  22          mikedrinksbeer2
#  23               dbmernin83
#  24           titosupertramp
#  25              optimator13
#  26                Blakaeris
#  27                  bashiba
#  28                     Klym
#  29                flexabull
#                   ...
#  1586584            dherling
#  1586585              tgbljb
#  1586586                cbl2
#  1586587                 BBM
#  1586588            Buddha22
#  1586589          JohnQVegas
#  1586590          cpanossian
#  1586591            claspada
#  1586592          RblWthACoz
#  1586593           yelterdow
#  1586594          maddogruss
#  1586595        JerzDevl2000
#  1586596          hoppymcgee
#  1586597              WesWes
#  1586598           Slatetank
#  1586599           Lenny2884
#  1586600          ummswimmin
#  1586601             pzrhsau
#  1586602            asabreed
#  1586603                infi
#  1586604             njmoons
#  1586605          NyackNicky
#  1586606     blitheringidiot
#  1586607              PopeDX
#  1586608     treehugger02010
#  1586609          maddogruss
#  1586610           yelterdow
#  1586611            TongoRad
#  1586612            dherling
#  1586613                cbl2
#  Name: review_profilename, Length: 1586614, dtype: object,
#  'review_taste': 0          1.5
#  1          3.0
#  2          3.0
#  3          3.0
#  4          4.5
#  5          3.5
#  6          4.0
#  7          3.5
#  8          4.0
#  9          4.0
#  10         2.5
#  11         4.0
#  12         4.0
#  13         3.0
#  14         4.0
#  15         3.0
#  16         2.0
#  17         4.0
#  18         2.0
#  19         4.5
#  20         4.0
#  21         4.0
#  22         4.5
#  23         4.5
#  24         4.5
#  25         5.0
#  26         4.5
#  27         4.0
#  28         4.5
#  29         4.0
#            ...
#  1586584    4.0
#  1586585    3.5
#  1586586    3.5
#  1586587    4.0
#  1586588    2.5
#  1586589    1.0
#  1586590    1.5
#  1586591    1.0
#  1586592    4.5
#  1586593    4.0
#  1586594    4.0
#  1586595    4.0
#  1586596    3.5
#  1586597    4.0
#  1586598    4.5
#  1586599    4.0
#  1586600    3.5
#  1586601    4.0
#  1586602    4.0
#  1586603    4.0
#  1586604    3.5
#  1586605    5.0
#  1586606    5.0
#  1586607    4.5
#  1586608    3.0
#  1586609    4.0
#  1586610    4.0
#  1586611    4.0
#  1586612    4.5
#  1586613    4.5
#  Name: review_taste, Length: 1586614, dtype: float64}

# %%
# Define Margin of Error and Z-score for 95% confidence interval
mError = 0.1
zScore = 1.96

def prep_data_frame(_list):
    """
    _list: list of column headers. Example: ["beer_beerid","beer_name",..]
    """
    _dict = {header: reviews[header] for header in _list}
    return pd.DataFrame.from_dict(_dict)
    
def calculate_stats(key, data_frame):
    _df = data_frame.groupby(level=0)
    samples = _df.count().rename(columns={key: 'count'})
    means = _df.mean().rename(columns={key: 'mean'})
    std = _df.std().rename(columns={key:'std'})
    return pd.concat([samples, means, std], axis=1)
    

beer_identifiers = df[['beer_beerid','beer_name', 'beer_style', 'review_profilename']]
reviews_means = dict()
for key in ['review_overall', 'review_aroma', 'review_taste', 'review_appearance', 'review_palate']:
    
    # create df for each review
    ids = prep_data_frame(beer_identifiers)
    review = prep_data_frame([key])
    data_frame = pd.concat([ids, review], axis=1).drop_duplicates(['beer_beerid','review_profilename'])
    
    # Filter rows and keep items that meet criteria
    stats = calculate_stats(key, data_frame.set_index(["beer_beerid","beer_name"]))
    stats = stats[stats['std'] != 0] # Remove rows with zero std dev
    stats['required'] = stats['std'].map(lambda x:(x *zScore/mError)**2) 
    # Add a new row with required number samples
    beer_ids = [idx for idx in stats.index if stats.loc[idx, 'count'] > stats.loc[idx, 'required']]
    mean_values = [stats.loc[idx, 'mean'] for idx in beer_ids]

    # Drop duplicates
    data_frame = data_frame.drop_duplicates(['beer_beerid']).drop('review_profilename', axis=1)

    # Only keep the beers meet requirements 
    review_data_frame = data_frame.set_index(['beer_beerid'])

    review_data_frame = review_data_frame.drop([Id for Id in review_data_frame.index if Id not in beer_ids])

    
    #Create df for reviews
    reviews_means.update({
        key : review_data_frame.reset_index()
    })
# Out:
# C:\Users\victo\Anaconda3\lib\site-packages\ipykernel_launcher.py:34: RuntimeWarning: invalid value encountered in greater

# %%
prep_data_frame
# Out:
# <function __main__.prep_data_frame>

# %% [markdown]
# ## Question 3: Which of the factors (aroma, taste, appearance, palette) are most important in determining the overall quality of a beer?
#
# ## Question 4: If I typically enjoy a beer due to its aroma and appearance, which beer style should I try?

# %%
df_overall = reviews_means['review_overall'].set_index(['beer_beerid'])
df_overall = df_overall.sort_values(by='review_overall', ascending=False)
df_overall.head(10)
# Out:
#                                                  beer_name  \
# beer_beerid
# 34909        Stone Old Guardian Barley Wine Style Ale 2007
# 4083                                   Stone Ruination IPA
# 2654                              Left Hand Imperial Stout
# 53433                                Unplugged Cranbic Ale
# 32360                           Stone 10th Anniversary IPA
# 637                                       Old Speckled Hen
# 411                                              Pranqster
# 64545                                  Double Sunshine IPA
# 41043                                  Double Dead Guy Ale
# 66036                  Stone Old Guardian BELGO Barleywine
#
#                                  beer_style  review_overall
# beer_beerid
# 34909                   American Barleywine             5.0
# 4083         American Double / Imperial IPA             5.0
# 2654                 Russian Imperial Stout             5.0
# 53433                     American Wild Ale             5.0
# 32360        American Double / Imperial IPA             5.0
# 637                        English Pale Ale             5.0
# 411                 Belgian Strong Pale Ale             5.0
# 64545        American Double / Imperial IPA             5.0
# 41043                   American Strong Ale             5.0
# 66036                   American Barleywine             5.0

# %%
df_aroma = reviews_means['review_aroma'].set_index(['beer_beerid'])
df_aroma =df_aroma.sort_values(by='review_aroma', ascending=False)
df_aroma.head(10)
# Out:
#                                  beer_name               beer_style  \
# beer_beerid
# 1440                   Bailey's Blonde Ale      American Blonde Ale
# 705          J.W. Lees Vintage Harvest Ale       English Barleywine
# 46984         John Henry 3 Lick Spiker Ale      American Strong Ale
# 6305             Drie Fonteinen Oude Geuze                   Gueuze
# 42349          Vanilla Bean Aged Dark Lord   Russian Imperial Stout
# 645                Trappistes Rochefort 10         Quadrupel (Quad)
# 51619               Ommegang Adoration Ale  Belgian Strong Dark Ale
# 27604                             Duet IPA             American IPA
# 1836                            La Chouffe  Belgian Strong Pale Ale
# 3916                          AleSmith IPA             American IPA
#
#              review_aroma
# beer_beerid
# 1440                  5.0
# 705                   5.0
# 46984                 5.0
# 6305                  5.0
# 42349                 5.0
# 645                   5.0
# 51619                 5.0
# 27604                 5.0
# 1836                  5.0
# 3916                  5.0

# %%
df_appear = reviews_means['review_appearance'].set_index(['beer_beerid'])
df_appear = df_appear.sort_values(by='review_appearance', ascending=False)
df_appear.head(10)
# Out:
#                                              beer_name  \
# beer_beerid
# 1836                                        La Chouffe
# 3877         Dark Horse Reserve Special Black Bier Ale
# 73427                               Blaecorn Unidragon
# 44727                             Portsmouth 5 C's IPA
# 8848                        Dark Horse Boffo Brown Ale
# 2196                       Herold Bohemian Black Lager
# 7284                                YuleSmith (Summer)
# 44568                                   Loser Pale Ale
# 63422                                           Either
# 55382           Collaboration No. 1 - Imperial Pilsner
#
#                                      beer_style  review_appearance
# beer_beerid
# 1836                    Belgian Strong Pale Ale                5.0
# 3877                        American Strong Ale                5.0
# 73427                    Russian Imperial Stout                5.0
# 44727                              American IPA                5.0
# 8848                          English Brown Ale                5.0
# 2196                                Schwarzbier                5.0
# 7284             American Double / Imperial IPA                5.0
# 44568                   American Pale Ale (APA)                5.0
# 63422                        American Black Ale                5.0
# 55382        American Double / Imperial Pilsner                5.0

# %%
df_palate = reviews_means['review_palate'].set_index(['beer_beerid'])
df_palate = df_palate.sort_values(by='review_palate', ascending=False)
df_palate.head(10)
# Out:
#                                      beer_name  \
# beer_beerid
# 17112                       Bell's Hopslam Ale
# 30                              Trois Pistoles
# 42349              Vanilla Bean Aged Dark Lord
# 129                         Orval Trappist Ale
# 26072         Noire De Chambly / Chambly Noire
# 356                             Imperial Stout
# 46080                           Apocalypse Cow
# 55564                           Red Chair NWPA
# 30184        Oak Aged Dark Lord Imperial Stout
# 37294                 Dark Horizon 1st Edition
#
#                                  beer_style  review_palate
# beer_beerid
# 17112        American Double / Imperial IPA            5.0
# 30                  Belgian Strong Dark Ale            5.0
# 42349                Russian Imperial Stout            5.0
# 129                        Belgian Pale Ale            5.0
# 26072                      Belgian Dark Ale            5.0
# 356                  Russian Imperial Stout            5.0
# 46080        American Double / Imperial IPA            5.0
# 55564               American Pale Ale (APA)            5.0
# 30184                Russian Imperial Stout            5.0
# 37294                Russian Imperial Stout            5.0

# %%
df_taste = reviews_means['review_taste'].set_index(['beer_beerid'])
df_taste  = df_taste .sort_values(by='review_taste', ascending=False)
df_taste.head(10)
# Out:
#                                                  beer_name  \
# beer_beerid
# 30184                    Oak Aged Dark Lord Imperial Stout
# 38094                        Toronado 20th Anniversary Ale
# 1836                                            La Chouffe
# 27286                          Arcadia HopMouth Double IPA
# 2803                                                   Sol
# 3833                               AleSmith Speedway Stout
# 33127                                             Darkness
# 30                                          Trois Pistoles
# 20168                                    Hoptical Illusion
# 48505        Victory At Sea Coffee Vanilla Imperial Porter
#
#                                    beer_style  review_taste
# beer_beerid
# 30184                  Russian Imperial Stout           5.0
# 38094                       American Wild Ale           5.0
# 1836                  Belgian Strong Pale Ale           5.0
# 27286          American Double / Imperial IPA           5.0
# 2803                   American Adjunct Lager           5.0
# 3833         American Double / Imperial Stout           5.0
# 33127                  Russian Imperial Stout           5.0
# 30                    Belgian Strong Dark Ale           5.0
# 20168                            American IPA           5.0
# 48505                         American Porter           5.0
